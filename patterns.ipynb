# %%
///#1523/
///////low = int(input())
high = int(input())
count = (high-low)+1
if low%2!=0 and high%2!=0:
  print((count//2)+1)
else:
  print(count//2)

# %%
#326
n=int(input())
while n%3==0:
  n//=3
print(n==1)
# Out:
# 5
# False

# %%
n=int(input())
for i in range(1,n+1):
  print("*"*i)
# Out:
# 5
# *
# **
# ***
# ****
# *****

# %%
n=int(input())
for i in range(1,n+1):
  print("*"*n)
# Out:
# 5
# *****
# *****
# *****
# *****
# *****

# %%
n=int(input())
for i in  range(n,0,-1):
  print("*"*i)
# Out:
# 5
# *****
# ****
# ***
# **
# *

# %%
n=int(input())
for i in range(1,n+1):
  print("*"*i)
for j in range(n,0,-1):
  print("*"*j)
# Out:
# 2
# *
# **
# **
# *

# %%
n=int(input())
for i in range(1,n+1):
  print("*"*i +" "*(n-i))
for j in range(n,0,-1):
  print("*"*j +" "*(n-j))
# Out:
# 5
# *
# **
# ***
# ****
# *****
# *****
# ****
# ***
# **
# *

# %%
n = int(input())
for i in range(1,n+1):
    print(" "*(n-i) + "*"*i)
for i in range(n,0,-1):
    print(" "*(n-i) + "*"*i)
